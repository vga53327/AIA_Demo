# %%
import warnings
warnings.filterwarnings('ignore')

import tensorflow.keras as keras
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.models import Sequential, load_model, Model
from tensorflow.keras.layers import Dense, Dropout, Activation, Flatten
from tensorflow.keras.layers import Conv2D, MaxPooling2D, BatchNormalization, GlobalAveragePooling2D
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
from tensorflow.keras.applications.xception import Xception

import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

from utils import load_data, load_test_data
from utils import num_classes, epochs, batch_size
# Out:
# ./mapping.txt

# %%
X_train, y_train, X_valid, y_valid = load_data(Gray2RGB=True, img_size = 299,
                                               mean_proc=None, test_size=0.1)

# %% [markdown]
# # Xception Fine Tuning

# %%
model_name = 'Xception-Fine-Tune'

img_rows, img_cols, img_channel = 299, 299, 3
base_model = Xception(weights='imagenet', include_top=False,
                         input_shape=(img_rows, img_cols, img_channel))

x = base_model.output
x = GlobalAveragePooling2D(data_format='channels_last')(x)
x = Dropout(0.5)(x)
predictions = Dense(num_classes, activation='softmax')(x)

model = Model(inputs=base_model.input, outputs=predictions)

model.summary()
# Out:
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            (None, 299, 299, 3)  0
# __________________________________________________________________________________________________
# block1_conv1 (Conv2D)           (None, 149, 149, 32) 864         input_1[0][0]
# __________________________________________________________________________________________________
# block1_conv1_bn (BatchNormaliza (None, 149, 149, 32) 128         block1_conv1[0][0]
# __________________________________________________________________________________________________
# block1_conv1_act (Activation)   (None, 149, 149, 32) 0           block1_conv1_bn[0][0]
# __________________________________________________________________________________________________
# block1_conv2 (Conv2D)           (None, 147, 147, 64) 18432       block1_conv1_act[0][0]
# __________________________________________________________________________________________________
# block1_conv2_bn (BatchNormaliza (None, 147, 147, 64) 256         block1_conv2[0][0]
# __________________________________________________________________________________________________
# block1_conv2_act (Activation)   (None, 147, 147, 64) 0           block1_conv2_bn[0][0]
# __________________________________________________________________________________________________
# block2_sepconv1 (SeparableConv2 (None, 147, 147, 128 8768        block1_conv2_act[0][0]
# __________________________________________________________________________________________________
# block2_sepconv1_bn (BatchNormal (None, 147, 147, 128 512         block2_sepconv1[0][0]
# __________________________________________________________________________________________________
# block2_sepconv2_act (Activation (None, 147, 147, 128 0           block2_sepconv1_bn[0][0]
# __________________________________________________________________________________________________
# block2_sepconv2 (SeparableConv2 (None, 147, 147, 128 17536       block2_sepconv2_act[0][0]
# __________________________________________________________________________________________________
# block2_sepconv2_bn (BatchNormal (None, 147, 147, 128 512         block2_sepconv2[0][0]
# __________________________________________________________________________________________________
# conv2d (Conv2D)                 (None, 74, 74, 128)  8192        block1_conv2_act[0][0]
# __________________________________________________________________________________________________
# block2_pool (MaxPooling2D)      (None, 74, 74, 128)  0           block2_sepconv2_bn[0][0]
# __________________________________________________________________________________________________
# batch_normalization (BatchNorma (None, 74, 74, 128)  512         conv2d[0][0]
# __________________________________________________________________________________________________
# add (Add)                       (None, 74, 74, 128)  0           block2_pool[0][0]
#                                                                  batch_normalization[0][0]
# __________________________________________________________________________________________________
# block3_sepconv1_act (Activation (None, 74, 74, 128)  0           add[0][0]
# __________________________________________________________________________________________________
# block3_sepconv1 (SeparableConv2 (None, 74, 74, 256)  33920       block3_sepconv1_act[0][0]
# __________________________________________________________________________________________________
# block3_sepconv1_bn (BatchNormal (None, 74, 74, 256)  1024        block3_sepconv1[0][0]
# __________________________________________________________________________________________________
# block3_sepconv2_act (Activation (None, 74, 74, 256)  0           block3_sepconv1_bn[0][0]
# __________________________________________________________________________________________________
# block3_sepconv2 (SeparableConv2 (None, 74, 74, 256)  67840       block3_sepconv2_act[0][0]
# __________________________________________________________________________________________________
# block3_sepconv2_bn (BatchNormal (None, 74, 74, 256)  1024        block3_sepconv2[0][0]
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 37, 37, 256)  32768       add[0][0]
# __________________________________________________________________________________________________
# block3_pool (MaxPooling2D)      (None, 37, 37, 256)  0           block3_sepconv2_bn[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 37, 37, 256)  1024        conv2d_1[0][0]
# __________________________________________________________________________________________________
# add_1 (Add)                     (None, 37, 37, 256)  0           block3_pool[0][0]
#                                                                  batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# block4_sepconv1_act (Activation (None, 37, 37, 256)  0           add_1[0][0]
# __________________________________________________________________________________________________
# block4_sepconv1 (SeparableConv2 (None, 37, 37, 728)  188672      block4_sepconv1_act[0][0]
# __________________________________________________________________________________________________
# block4_sepconv1_bn (BatchNormal (None, 37, 37, 728)  2912        block4_sepconv1[0][0]
# __________________________________________________________________________________________________
# block4_sepconv2_act (Activation (None, 37, 37, 728)  0           block4_sepconv1_bn[0][0]
# __________________________________________________________________________________________________
# block4_sepconv2 (SeparableConv2 (None, 37, 37, 728)  536536      block4_sepconv2_act[0][0]
# __________________________________________________________________________________________________
# block4_sepconv2_bn (BatchNormal (None, 37, 37, 728)  2912        block4_sepconv2[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 19, 19, 728)  186368      add_1[0][0]
# __________________________________________________________________________________________________
# block4_pool (MaxPooling2D)      (None, 19, 19, 728)  0           block4_sepconv2_bn[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, 19, 19, 728)  2912        conv2d_2[0][0]
# __________________________________________________________________________________________________
# add_2 (Add)                     (None, 19, 19, 728)  0           block4_pool[0][0]
#                                                                  batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# block5_sepconv1_act (Activation (None, 19, 19, 728)  0           add_2[0][0]
# __________________________________________________________________________________________________
# block5_sepconv1 (SeparableConv2 (None, 19, 19, 728)  536536      block5_sepconv1_act[0][0]
# __________________________________________________________________________________________________
# block5_sepconv1_bn (BatchNormal (None, 19, 19, 728)  2912        block5_sepconv1[0][0]
# __________________________________________________________________________________________________
# block5_sepconv2_act (Activation (None, 19, 19, 728)  0           block5_sepconv1_bn[0][0]
# __________________________________________________________________________________________________
# block5_sepconv2 (SeparableConv2 (None, 19, 19, 728)  536536      block5_sepconv2_act[0][0]
# __________________________________________________________________________________________________
# block5_sepconv2_bn (BatchNormal (None, 19, 19, 728)  2912        block5_sepconv2[0][0]
# __________________________________________________________________________________________________
# block5_sepconv3_act (Activation (None, 19, 19, 728)  0           block5_sepconv2_bn[0][0]
# __________________________________________________________________________________________________
# block5_sepconv3 (SeparableConv2 (None, 19, 19, 728)  536536      block5_sepconv3_act[0][0]
# __________________________________________________________________________________________________
# block5_sepconv3_bn (BatchNormal (None, 19, 19, 728)  2912        block5_sepconv3[0][0]
# __________________________________________________________________________________________________
# add_3 (Add)                     (None, 19, 19, 728)  0           block5_sepconv3_bn[0][0]
#                                                                  add_2[0][0]
# __________________________________________________________________________________________________
# block6_sepconv1_act (Activation (None, 19, 19, 728)  0           add_3[0][0]
# __________________________________________________________________________________________________
# block6_sepconv1 (SeparableConv2 (None, 19, 19, 728)  536536      block6_sepconv1_act[0][0]
# __________________________________________________________________________________________________
# block6_sepconv1_bn (BatchNormal (None, 19, 19, 728)  2912        block6_sepconv1[0][0]
# __________________________________________________________________________________________________
# block6_sepconv2_act (Activation (None, 19, 19, 728)  0           block6_sepconv1_bn[0][0]
# __________________________________________________________________________________________________
# block6_sepconv2 (SeparableConv2 (None, 19, 19, 728)  536536      block6_sepconv2_act[0][0]
# __________________________________________________________________________________________________
# block6_sepconv2_bn (BatchNormal (None, 19, 19, 728)  2912        block6_sepconv2[0][0]
# __________________________________________________________________________________________________
# block6_sepconv3_act (Activation (None, 19, 19, 728)  0           block6_sepconv2_bn[0][0]
# __________________________________________________________________________________________________
# block6_sepconv3 (SeparableConv2 (None, 19, 19, 728)  536536      block6_sepconv3_act[0][0]
# __________________________________________________________________________________________________
# block6_sepconv3_bn (BatchNormal (None, 19, 19, 728)  2912        block6_sepconv3[0][0]
# __________________________________________________________________________________________________
# add_4 (Add)                     (None, 19, 19, 728)  0           block6_sepconv3_bn[0][0]
#                                                                  add_3[0][0]
# __________________________________________________________________________________________________
# block7_sepconv1_act (Activation (None, 19, 19, 728)  0           add_4[0][0]
# __________________________________________________________________________________________________
# block7_sepconv1 (SeparableConv2 (None, 19, 19, 728)  536536      block7_sepconv1_act[0][0]
# __________________________________________________________________________________________________
# block7_sepconv1_bn (BatchNormal (None, 19, 19, 728)  2912        block7_sepconv1[0][0]
# __________________________________________________________________________________________________
# block7_sepconv2_act (Activation (None, 19, 19, 728)  0           block7_sepconv1_bn[0][0]
# __________________________________________________________________________________________________
# block7_sepconv2 (SeparableConv2 (None, 19, 19, 728)  536536      block7_sepconv2_act[0][0]
# __________________________________________________________________________________________________
# block7_sepconv2_bn (BatchNormal (None, 19, 19, 728)  2912        block7_sepconv2[0][0]
# __________________________________________________________________________________________________
# block7_sepconv3_act (Activation (None, 19, 19, 728)  0           block7_sepconv2_bn[0][0]
# __________________________________________________________________________________________________
# block7_sepconv3 (SeparableConv2 (None, 19, 19, 728)  536536      block7_sepconv3_act[0][0]
# __________________________________________________________________________________________________
# block7_sepconv3_bn (BatchNormal (None, 19, 19, 728)  2912        block7_sepconv3[0][0]
# __________________________________________________________________________________________________
# add_5 (Add)                     (None, 19, 19, 728)  0           block7_sepconv3_bn[0][0]
#                                                                  add_4[0][0]
# __________________________________________________________________________________________________
# block8_sepconv1_act (Activation (None, 19, 19, 728)  0           add_5[0][0]
# __________________________________________________________________________________________________
# block8_sepconv1 (SeparableConv2 (None, 19, 19, 728)  536536      block8_sepconv1_act[0][0]
# __________________________________________________________________________________________________
# block8_sepconv1_bn (BatchNormal (None, 19, 19, 728)  2912        block8_sepconv1[0][0]
# __________________________________________________________________________________________________
# block8_sepconv2_act (Activation (None, 19, 19, 728)  0           block8_sepconv1_bn[0][0]
# __________________________________________________________________________________________________
# block8_sepconv2 (SeparableConv2 (None, 19, 19, 728)  536536      block8_sepconv2_act[0][0]
# __________________________________________________________________________________________________
# block8_sepconv2_bn (BatchNormal (None, 19, 19, 728)  2912        block8_sepconv2[0][0]
# __________________________________________________________________________________________________
# block8_sepconv3_act (Activation (None, 19, 19, 728)  0           block8_sepconv2_bn[0][0]
# __________________________________________________________________________________________________
# block8_sepconv3 (SeparableConv2 (None, 19, 19, 728)  536536      block8_sepconv3_act[0][0]
# __________________________________________________________________________________________________
# block8_sepconv3_bn (BatchNormal (None, 19, 19, 728)  2912        block8_sepconv3[0][0]
# __________________________________________________________________________________________________
# add_6 (Add)                     (None, 19, 19, 728)  0           block8_sepconv3_bn[0][0]
#                                                                  add_5[0][0]
# __________________________________________________________________________________________________
# block9_sepconv1_act (Activation (None, 19, 19, 728)  0           add_6[0][0]
# __________________________________________________________________________________________________
# block9_sepconv1 (SeparableConv2 (None, 19, 19, 728)  536536      block9_sepconv1_act[0][0]
# __________________________________________________________________________________________________
# block9_sepconv1_bn (BatchNormal (None, 19, 19, 728)  2912        block9_sepconv1[0][0]
# __________________________________________________________________________________________________
# block9_sepconv2_act (Activation (None, 19, 19, 728)  0           block9_sepconv1_bn[0][0]
# __________________________________________________________________________________________________
# block9_sepconv2 (SeparableConv2 (None, 19, 19, 728)  536536      block9_sepconv2_act[0][0]
# __________________________________________________________________________________________________
# block9_sepconv2_bn (BatchNormal (None, 19, 19, 728)  2912        block9_sepconv2[0][0]
# __________________________________________________________________________________________________
# block9_sepconv3_act (Activation (None, 19, 19, 728)  0           block9_sepconv2_bn[0][0]
# __________________________________________________________________________________________________
# block9_sepconv3 (SeparableConv2 (None, 19, 19, 728)  536536      block9_sepconv3_act[0][0]
# __________________________________________________________________________________________________
# block9_sepconv3_bn (BatchNormal (None, 19, 19, 728)  2912        block9_sepconv3[0][0]
# __________________________________________________________________________________________________
# add_7 (Add)                     (None, 19, 19, 728)  0           block9_sepconv3_bn[0][0]
#                                                                  add_6[0][0]
# __________________________________________________________________________________________________
# block10_sepconv1_act (Activatio (None, 19, 19, 728)  0           add_7[0][0]
# __________________________________________________________________________________________________
# block10_sepconv1 (SeparableConv (None, 19, 19, 728)  536536      block10_sepconv1_act[0][0]
# __________________________________________________________________________________________________
# block10_sepconv1_bn (BatchNorma (None, 19, 19, 728)  2912        block10_sepconv1[0][0]
# __________________________________________________________________________________________________
# block10_sepconv2_act (Activatio (None, 19, 19, 728)  0           block10_sepconv1_bn[0][0]
# __________________________________________________________________________________________________
# block10_sepconv2 (SeparableConv (None, 19, 19, 728)  536536      block10_sepconv2_act[0][0]
# __________________________________________________________________________________________________
# block10_sepconv2_bn (BatchNorma (None, 19, 19, 728)  2912        block10_sepconv2[0][0]
# __________________________________________________________________________________________________
# block10_sepconv3_act (Activatio (None, 19, 19, 728)  0           block10_sepconv2_bn[0][0]
# __________________________________________________________________________________________________
# block10_sepconv3 (SeparableConv (None, 19, 19, 728)  536536      block10_sepconv3_act[0][0]
# __________________________________________________________________________________________________
# block10_sepconv3_bn (BatchNorma (None, 19, 19, 728)  2912        block10_sepconv3[0][0]
# __________________________________________________________________________________________________
# add_8 (Add)                     (None, 19, 19, 728)  0           block10_sepconv3_bn[0][0]
#                                                                  add_7[0][0]
# __________________________________________________________________________________________________
# block11_sepconv1_act (Activatio (None, 19, 19, 728)  0           add_8[0][0]
# __________________________________________________________________________________________________
# block11_sepconv1 (SeparableConv (None, 19, 19, 728)  536536      block11_sepconv1_act[0][0]
# __________________________________________________________________________________________________
# block11_sepconv1_bn (BatchNorma (None, 19, 19, 728)  2912        block11_sepconv1[0][0]
# __________________________________________________________________________________________________
# block11_sepconv2_act (Activatio (None, 19, 19, 728)  0           block11_sepconv1_bn[0][0]
# __________________________________________________________________________________________________
# block11_sepconv2 (SeparableConv (None, 19, 19, 728)  536536      block11_sepconv2_act[0][0]
# __________________________________________________________________________________________________
# block11_sepconv2_bn (BatchNorma (None, 19, 19, 728)  2912        block11_sepconv2[0][0]
# __________________________________________________________________________________________________
# block11_sepconv3_act (Activatio (None, 19, 19, 728)  0           block11_sepconv2_bn[0][0]
# __________________________________________________________________________________________________
# block11_sepconv3 (SeparableConv (None, 19, 19, 728)  536536      block11_sepconv3_act[0][0]
# __________________________________________________________________________________________________
# block11_sepconv3_bn (BatchNorma (None, 19, 19, 728)  2912        block11_sepconv3[0][0]
# __________________________________________________________________________________________________
# add_9 (Add)                     (None, 19, 19, 728)  0           block11_sepconv3_bn[0][0]
#                                                                  add_8[0][0]
# __________________________________________________________________________________________________
# block12_sepconv1_act (Activatio (None, 19, 19, 728)  0           add_9[0][0]
# __________________________________________________________________________________________________
# block12_sepconv1 (SeparableConv (None, 19, 19, 728)  536536      block12_sepconv1_act[0][0]
# __________________________________________________________________________________________________
# block12_sepconv1_bn (BatchNorma (None, 19, 19, 728)  2912        block12_sepconv1[0][0]
# __________________________________________________________________________________________________
# block12_sepconv2_act (Activatio (None, 19, 19, 728)  0           block12_sepconv1_bn[0][0]
# __________________________________________________________________________________________________
# block12_sepconv2 (SeparableConv (None, 19, 19, 728)  536536      block12_sepconv2_act[0][0]
# __________________________________________________________________________________________________
# block12_sepconv2_bn (BatchNorma (None, 19, 19, 728)  2912        block12_sepconv2[0][0]
# __________________________________________________________________________________________________
# block12_sepconv3_act (Activatio (None, 19, 19, 728)  0           block12_sepconv2_bn[0][0]
# __________________________________________________________________________________________________
# block12_sepconv3 (SeparableConv (None, 19, 19, 728)  536536      block12_sepconv3_act[0][0]
# __________________________________________________________________________________________________
# block12_sepconv3_bn (BatchNorma (None, 19, 19, 728)  2912        block12_sepconv3[0][0]
# __________________________________________________________________________________________________
# add_10 (Add)                    (None, 19, 19, 728)  0           block12_sepconv3_bn[0][0]
#                                                                  add_9[0][0]
# __________________________________________________________________________________________________
# block13_sepconv1_act (Activatio (None, 19, 19, 728)  0           add_10[0][0]
# __________________________________________________________________________________________________
# block13_sepconv1 (SeparableConv (None, 19, 19, 728)  536536      block13_sepconv1_act[0][0]
# __________________________________________________________________________________________________
# block13_sepconv1_bn (BatchNorma (None, 19, 19, 728)  2912        block13_sepconv1[0][0]
# __________________________________________________________________________________________________
# block13_sepconv2_act (Activatio (None, 19, 19, 728)  0           block13_sepconv1_bn[0][0]
# __________________________________________________________________________________________________
# block13_sepconv2 (SeparableConv (None, 19, 19, 1024) 752024      block13_sepconv2_act[0][0]
# __________________________________________________________________________________________________
# block13_sepconv2_bn (BatchNorma (None, 19, 19, 1024) 4096        block13_sepconv2[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 10, 10, 1024) 745472      add_10[0][0]
# __________________________________________________________________________________________________
# block13_pool (MaxPooling2D)     (None, 10, 10, 1024) 0           block13_sepconv2_bn[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, 10, 10, 1024) 4096        conv2d_3[0][0]
# __________________________________________________________________________________________________
# add_11 (Add)                    (None, 10, 10, 1024) 0           block13_pool[0][0]
#                                                                  batch_normalization_3[0][0]
# __________________________________________________________________________________________________
# block14_sepconv1 (SeparableConv (None, 10, 10, 1536) 1582080     add_11[0][0]
# __________________________________________________________________________________________________
# block14_sepconv1_bn (BatchNorma (None, 10, 10, 1536) 6144        block14_sepconv1[0][0]
# __________________________________________________________________________________________________
# block14_sepconv1_act (Activatio (None, 10, 10, 1536) 0           block14_sepconv1_bn[0][0]
# __________________________________________________________________________________________________
# block14_sepconv2 (SeparableConv (None, 10, 10, 2048) 3159552     block14_sepconv1_act[0][0]
# __________________________________________________________________________________________________
# block14_sepconv2_bn (BatchNorma (None, 10, 10, 2048) 8192        block14_sepconv2[0][0]
# __________________________________________________________________________________________________
# block14_sepconv2_act (Activatio (None, 10, 10, 2048) 0           block14_sepconv2_bn[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d (Globa (None, 2048)         0           block14_sepconv2_act[0][0]
# __________________________________________________________________________________________________
# dropout (Dropout)               (None, 2048)         0           global_average_pooling2d[0][0]
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 5)            10245       dropout[0][0]
# ==================================================================================================
# Total params: 20,871,725
# Trainable params: 20,817,197
# Non-trainable params: 54,528
# __________________________________________________________________________________________________

# %%
datagen = ImageDataGenerator(
    rotation_range=10,
    width_shift_range=0.5,
    height_shift_range=0.1,
    shear_range=0.1,
    zoom_range=0.1,
    horizontal_flip=True,
    fill_mode='nearest')

optimizer = keras.optimizers.Adam(lr=10e-6)

model_path = './saved_models/{}.h5'.format(model_name)

checkpoint = ModelCheckpoint(model_path, monitor='val_loss', save_best_only=True, verbose=1)
earlystop = EarlyStopping(monitor='val_loss', patience=5, verbose=1)

model.compile(loss='categorical_crossentropy',
              optimizer=optimizer, metrics=['accuracy'])

batch_size = 10
model_history = model.fit_generator(datagen.flow(X_train, y_train, batch_size = batch_size),
                                    epochs = epochs,
                                    validation_data = (X_valid, y_valid),
                                    callbacks = [checkpoint, earlystop])
# Out:
# Epoch 1/100
# 48/49 [============================>.] - ETA: 0s - loss: 1.6967 - acc: 0.1792
# Epoch 00001: val_loss improved from inf to 1.59263, saving model to ./saved_models/Xception-Fine-Tune.h5
# 49/49 [==============================] - 34s 694ms/step - loss: 1.6933 - acc: 0.1796 - val_loss: 1.5926 - val_acc: 0.2407
# Epoch 2/100
# 48/49 [============================>.] - ETA: 0s - loss: 1.6522 - acc: 0.2271
# Epoch 00002: val_loss improved from 1.59263 to 1.57177, saving model to ./saved_models/Xception-Fine-Tune.h5
# 49/49 [==============================] - 15s 307ms/step - loss: 1.6502 - acc: 0.2307 - val_loss: 1.5718 - val_acc: 0.2963
# Epoch 3/100
# 48/49 [============================>.] - ETA: 0s - loss: 1.5858 - acc: 0.2625
# Epoch 00003: val_loss improved from 1.57177 to 1.56638, saving model to ./saved_models/Xception-Fine-Tune.h5
# 49/49 [==============================] - 15s 310ms/step - loss: 1.5804 - acc: 0.2723 - val_loss: 1.5664 - val_acc: 0.3333
# Epoch 4/100
# 48/49 [============================>.] - ETA: 0s - loss: 1.5629 - acc: 0.2792
# Epoch 00004: val_loss improved from 1.56638 to 1.55866, saving model to ./saved_models/Xception-Fine-Tune.h5
# 49/49 [==============================] - 15s 303ms/step - loss: 1.5662 - acc: 0.2756 - val_loss: 1.5587 - val_acc: 0.3704
# Epoch 5/100
# 48/49 [============================>.] - ETA: 0s - loss: 1.5376 - acc: 0.3354
# Epoch 00005: val_loss improved from 1.55866 to 1.54061, saving model to ./saved_models/Xception-Fine-Tune.h5
# 49/49 [==============================] - 15s 311ms/step - loss: 1.5339 - acc: 0.3387 - val_loss: 1.5406 - val_acc: 0.3519
# Epoch 6/100
# 48/49 [============================>.] - ETA: 0s - loss: 1.4811 - acc: 0.3760
# Epoch 00006: val_loss improved from 1.54061 to 1.51498, saving model to ./saved_models/Xception-Fine-Tune.h5
# 49/49 [==============================] - 16s 316ms/step - loss: 1.4829 - acc: 0.3766 - val_loss: 1.5150 - val_acc: 0.3889
# Epoch 7/100
# 48/49 [============================>.] - ETA: 0s - loss: 1.4395 - acc: 0.4167
# Epoch 00007: val_loss improved from 1.51498 to 1.48244, saving model to ./saved_models/Xception-Fine-Tune.h5
# 49/49 [==============================] - 15s 298ms/step - loss: 1.4386 - acc: 0.4183 - val_loss: 1.4824 - val_acc: 0.3889
# Epoch 8/100
# 48/49 [============================>.] - ETA: 0s - loss: 1.3631 - acc: 0.4677
# Epoch 00008: val_loss improved from 1.48244 to 1.44629, saving model to ./saved_models/Xception-Fine-Tune.h5
# 49/49 [==============================] - 15s 308ms/step - loss: 1.3664 - acc: 0.4601 - val_loss: 1.4463 - val_acc: 0.4259
# Epoch 9/100
# 48/49 [============================>.] - ETA: 0s - loss: 1.3134 - acc: 0.5177
# Epoch 00009: val_loss improved from 1.44629 to 1.40958, saving model to ./saved_models/Xception-Fine-Tune.h5
# 49/49 [==============================] - 16s 322ms/step - loss: 1.3132 - acc: 0.5215 - val_loss: 1.4096 - val_acc: 0.4444
# Epoch 10/100
# 48/49 [============================>.] - ETA: 0s - loss: 1.3157 - acc: 0.5031
# Epoch 00010: val_loss improved from 1.40958 to 1.37527, saving model to ./saved_models/Xception-Fine-Tune.h5
# 49/49 [==============================] - 16s 324ms/step - loss: 1.3156 - acc: 0.5011 - val_loss: 1.3753 - val_acc: 0.4444
# Epoch 11/100
# 48/49 [============================>.] - ETA: 0s - loss: 1.2479 - acc: 0.5542
# Epoch 00011: val_loss improved from 1.37527 to 1.33562, saving model to ./saved_models/Xception-Fine-Tune.h5
# 49/49 [==============================] - 15s 301ms/step - loss: 1.2476 - acc: 0.5550 - val_loss: 1.3356 - val_acc: 0.5000
# Epoch 12/100
# 48/49 [============================>.] - ETA: 0s - loss: 1.1990 - acc: 0.5688
# Epoch 00012: val_loss improved from 1.33562 to 1.28294, saving model to ./saved_models/Xception-Fine-Tune.h5
# 49/49 [==============================] - 15s 302ms/step - loss: 1.1962 - acc: 0.5694 - val_loss: 1.2829 - val_acc: 0.5556
# Epoch 13/100
# 48/49 [============================>.] - ETA: 0s - loss: 1.1307 - acc: 0.6281
# Epoch 00013: val_loss improved from 1.28294 to 1.22462, saving model to ./saved_models/Xception-Fine-Tune.h5
# 49/49 [==============================] - 15s 312ms/step - loss: 1.1350 - acc: 0.6234 - val_loss: 1.2246 - val_acc: 0.6111
# Epoch 14/100
# 48/49 [============================>.] - ETA: 0s - loss: 1.0745 - acc: 0.6573
# Epoch 00014: val_loss improved from 1.22462 to 1.15482, saving model to ./saved_models/Xception-Fine-Tune.h5
# 49/49 [==============================] - 16s 320ms/step - loss: 1.0775 - acc: 0.6542 - val_loss: 1.1548 - val_acc: 0.6296
# Epoch 15/100
# 48/49 [============================>.] - ETA: 0s - loss: 1.0128 - acc: 0.7063
# Epoch 00015: val_loss improved from 1.15482 to 1.09389, saving model to ./saved_models/Xception-Fine-Tune.h5
# 49/49 [==============================] - 15s 307ms/step - loss: 1.0095 - acc: 0.7082 - val_loss: 1.0939 - val_acc: 0.6667
# Epoch 16/100
# 48/49 [============================>.] - ETA: 0s - loss: 0.9566 - acc: 0.7365
# Epoch 00016: val_loss improved from 1.09389 to 1.04410, saving model to ./saved_models/Xception-Fine-Tune.h5
# 49/49 [==============================] - 15s 302ms/step - loss: 0.9546 - acc: 0.7378 - val_loss: 1.0441 - val_acc: 0.6852
# Epoch 17/100
# 48/49 [============================>.] - ETA: 0s - loss: 0.9025 - acc: 0.7708
# Epoch 00017: val_loss improved from 1.04410 to 0.97144, saving model to ./saved_models/Xception-Fine-Tune.h5
# 49/49 [==============================] - 15s 306ms/step - loss: 0.8994 - acc: 0.7714 - val_loss: 0.9714 - val_acc: 0.6852
# Epoch 18/100
# 48/49 [============================>.] - ETA: 0s - loss: 0.8242 - acc: 0.7594
# Epoch 00018: val_loss improved from 0.97144 to 0.91311, saving model to ./saved_models/Xception-Fine-Tune.h5
# 49/49 [==============================] - 15s 306ms/step - loss: 0.8243 - acc: 0.7602 - val_loss: 0.9131 - val_acc: 0.7222
# Epoch 19/100
# 48/49 [============================>.] - ETA: 0s - loss: 0.7910 - acc: 0.7958
# Epoch 00019: val_loss improved from 0.91311 to 0.86162, saving model to ./saved_models/Xception-Fine-Tune.h5
# 49/49 [==============================] - 15s 313ms/step - loss: 0.7952 - acc: 0.7897 - val_loss: 0.8616 - val_acc: 0.7593
# Epoch 20/100
# 48/49 [============================>.] - ETA: 0s - loss: 0.7442 - acc: 0.7969
# Epoch 00020: val_loss improved from 0.86162 to 0.82023, saving model to ./saved_models/Xception-Fine-Tune.h5
# 49/49 [==============================] - 16s 321ms/step - loss: 0.7411 - acc: 0.7991 - val_loss: 0.8202 - val_acc: 0.7593
# Epoch 21/100
# 48/49 [============================>.] - ETA: 0s - loss: 0.6778 - acc: 0.7896
# Epoch 00021: val_loss improved from 0.82023 to 0.74886, saving model to ./saved_models/Xception-Fine-Tune.h5
# 49/49 [==============================] - 15s 308ms/step - loss: 0.6804 - acc: 0.7897 - val_loss: 0.7489 - val_acc: 0.7593
# Epoch 22/100
# 48/49 [============================>.] - ETA: 0s - loss: 0.6384 - acc: 0.8073
# Epoch 00022: val_loss improved from 0.74886 to 0.71703, saving model to ./saved_models/Xception-Fine-Tune.h5
# 49/49 [==============================] - 15s 309ms/step - loss: 0.6371 - acc: 0.8073 - val_loss: 0.7170 - val_acc: 0.7778
# Epoch 23/100
# 48/49 [============================>.] - ETA: 0s - loss: 0.5975 - acc: 0.8375
# Epoch 00023: val_loss improved from 0.71703 to 0.67725, saving model to ./saved_models/Xception-Fine-Tune.h5
# 49/49 [==============================] - 15s 303ms/step - loss: 0.5947 - acc: 0.8389 - val_loss: 0.6772 - val_acc: 0.7778
# Epoch 24/100
# 48/49 [============================>.] - ETA: 0s - loss: 0.5403 - acc: 0.8677
# Epoch 00024: val_loss improved from 0.67725 to 0.64529, saving model to ./saved_models/Xception-Fine-Tune.h5
# 49/49 [==============================] - 15s 316ms/step - loss: 0.5476 - acc: 0.8623 - val_loss: 0.6453 - val_acc: 0.7778
# Epoch 25/100
# 48/49 [============================>.] - ETA: 0s - loss: 0.4997 - acc: 0.8802
# Epoch 00025: val_loss improved from 0.64529 to 0.63029, saving model to ./saved_models/Xception-Fine-Tune.h5
# 49/49 [==============================] - 16s 328ms/step - loss: 0.4995 - acc: 0.8808 - val_loss: 0.6303 - val_acc: 0.7778
# Epoch 26/100
# 48/49 [============================>.] - ETA: 0s - loss: 0.4983 - acc: 0.8687
# Epoch 00026: val_loss improved from 0.63029 to 0.62557, saving model to ./saved_models/Xception-Fine-Tune.h5
# 49/49 [==============================] - 15s 309ms/step - loss: 0.4966 - acc: 0.8695 - val_loss: 0.6256 - val_acc: 0.7778
# Epoch 27/100
# 48/49 [============================>.] - ETA: 0s - loss: 0.4192 - acc: 0.9104
# Epoch 00027: val_loss improved from 0.62557 to 0.60503, saving model to ./saved_models/Xception-Fine-Tune.h5
# 49/49 [==============================] - 15s 303ms/step - loss: 0.4298 - acc: 0.9041 - val_loss: 0.6050 - val_acc: 0.7593
# Epoch 28/100
# 48/49 [============================>.] - ETA: 0s - loss: 0.4262 - acc: 0.8979
# Epoch 00028: val_loss improved from 0.60503 to 0.56964, saving model to ./saved_models/Xception-Fine-Tune.h5
# 49/49 [==============================] - 17s 344ms/step - loss: 0.4239 - acc: 0.9000 - val_loss: 0.5696 - val_acc: 0.7963
# Epoch 29/100
# 48/49 [============================>.] - ETA: 0s - loss: 0.3635 - acc: 0.9312
# Epoch 00029: val_loss improved from 0.56964 to 0.55251, saving model to ./saved_models/Xception-Fine-Tune.h5
# 49/49 [==============================] - 15s 302ms/step - loss: 0.3615 - acc: 0.9306 - val_loss: 0.5525 - val_acc: 0.8148
# Epoch 30/100
# 48/49 [============================>.] - ETA: 0s - loss: 0.3521 - acc: 0.9333
# Epoch 00030: val_loss did not improve from 0.55251
# 49/49 [==============================] - 13s 266ms/step - loss: 0.3505 - acc: 0.9347 - val_loss: 0.5551 - val_acc: 0.7963
# Epoch 31/100
# 48/49 [============================>.] - ETA: 0s - loss: 0.3244 - acc: 0.9250
# Epoch 00031: val_loss improved from 0.55251 to 0.52475, saving model to ./saved_models/Xception-Fine-Tune.h5
# 49/49 [==============================] - 15s 306ms/step - loss: 0.3230 - acc: 0.9265 - val_loss: 0.5247 - val_acc: 0.8333
# Epoch 32/100
# 48/49 [============================>.] - ETA: 0s - loss: 0.3559 - acc: 0.9208
# Epoch 00032: val_loss improved from 0.52475 to 0.52277, saving model to ./saved_models/Xception-Fine-Tune.h5
# 49/49 [==============================] - 15s 305ms/step - loss: 0.3536 - acc: 0.9224 - val_loss: 0.5228 - val_acc: 0.8148
# Epoch 33/100
# 48/49 [============================>.] - ETA: 0s - loss: 0.3114 - acc: 0.9375
# Epoch 00033: val_loss improved from 0.52277 to 0.51833, saving model to ./saved_models/Xception-Fine-Tune.h5
# 49/49 [==============================] - 15s 306ms/step - loss: 0.3147 - acc: 0.9347 - val_loss: 0.5183 - val_acc: 0.8333
# Epoch 34/100
# 48/49 [============================>.] - ETA: 0s - loss: 0.2728 - acc: 0.9344
# Epoch 00034: val_loss improved from 0.51833 to 0.49738, saving model to ./saved_models/Xception-Fine-Tune.h5
# 49/49 [==============================] - 16s 320ms/step - loss: 0.2736 - acc: 0.9358 - val_loss: 0.4974 - val_acc: 0.8333
# Epoch 35/100
# 48/49 [============================>.] - ETA: 0s - loss: 0.2741 - acc: 0.9375
# Epoch 00035: val_loss did not improve from 0.49738
# 49/49 [==============================] - 13s 267ms/step - loss: 0.2840 - acc: 0.9337 - val_loss: 0.5345 - val_acc: 0.8519
# Epoch 36/100
# 48/49 [============================>.] - ETA: 0s - loss: 0.2347 - acc: 0.9542
# Epoch 00036: val_loss improved from 0.49738 to 0.47826, saving model to ./saved_models/Xception-Fine-Tune.h5
# 49/49 [==============================] - 15s 310ms/step - loss: 0.2330 - acc: 0.9530 - val_loss: 0.4783 - val_acc: 0.8333
# Epoch 37/100
# 48/49 [============================>.] - ETA: 0s - loss: 0.2309 - acc: 0.9562
# Epoch 00037: val_loss did not improve from 0.47826
# 49/49 [==============================] - 13s 270ms/step - loss: 0.2280 - acc: 0.9571 - val_loss: 0.5134 - val_acc: 0.8333
# Epoch 38/100
# 48/49 [============================>.] - ETA: 0s - loss: 0.2500 - acc: 0.9479
# Epoch 00038: val_loss did not improve from 0.47826
# 49/49 [==============================] - 13s 267ms/step - loss: 0.2485 - acc: 0.9469 - val_loss: 0.5363 - val_acc: 0.8148
# Epoch 39/100
# 48/49 [============================>.] - ETA: 0s - loss: 0.2264 - acc: 0.9344
# Epoch 00039: val_loss improved from 0.47826 to 0.47192, saving model to ./saved_models/Xception-Fine-Tune.h5
# 49/49 [==============================] - 15s 301ms/step - loss: 0.2242 - acc: 0.9358 - val_loss: 0.4719 - val_acc: 0.8519
# Epoch 40/100
# 48/49 [============================>.] - ETA: 0s - loss: 0.2384 - acc: 0.9406
# Epoch 00040: val_loss did not improve from 0.47192
# 49/49 [==============================] - 13s 267ms/step - loss: 0.2353 - acc: 0.9419 - val_loss: 0.4816 - val_acc: 0.8519
# Epoch 41/100
# 48/49 [============================>.] - ETA: 0s - loss: 0.1982 - acc: 0.9573
# Epoch 00041: val_loss improved from 0.47192 to 0.47140, saving model to ./saved_models/Xception-Fine-Tune.h5
# 49/49 [==============================] - 16s 319ms/step - loss: 0.1975 - acc: 0.9562 - val_loss: 0.4714 - val_acc: 0.8333
# Epoch 42/100
# 48/49 [============================>.] - ETA: 0s - loss: 0.1802 - acc: 0.9708
# Epoch 00042: val_loss did not improve from 0.47140
# 49/49 [==============================] - 13s 266ms/step - loss: 0.1785 - acc: 0.9714 - val_loss: 0.4833 - val_acc: 0.8333
# Epoch 43/100
# 48/49 [============================>.] - ETA: 0s - loss: 0.1655 - acc: 0.9708
# Epoch 00043: val_loss improved from 0.47140 to 0.46146, saving model to ./saved_models/Xception-Fine-Tune.h5
# 49/49 [==============================] - 15s 306ms/step - loss: 0.1634 - acc: 0.9714 - val_loss: 0.4615 - val_acc: 0.8704
# Epoch 44/100
# 48/49 [============================>.] - ETA: 0s - loss: 0.1850 - acc: 0.9552
# Epoch 00044: val_loss did not improve from 0.46146
# 49/49 [==============================] - 13s 269ms/step - loss: 0.1887 - acc: 0.9541 - val_loss: 0.4727 - val_acc: 0.8333
# Epoch 45/100
# 48/49 [============================>.] - ETA: 0s - loss: 0.1858 - acc: 0.9719
# Epoch 00045: val_loss did not improve from 0.46146
# 49/49 [==============================] - 13s 267ms/step - loss: 0.1849 - acc: 0.9725 - val_loss: 0.4728 - val_acc: 0.8519
# Epoch 46/100
# 48/49 [============================>.] - ETA: 0s - loss: 0.1671 - acc: 0.9583
# Epoch 00046: val_loss did not improve from 0.46146
# 49/49 [==============================] - 13s 268ms/step - loss: 0.1647 - acc: 0.9592 - val_loss: 0.4627 - val_acc: 0.8519
# Epoch 47/100
# 48/49 [============================>.] - ETA: 0s - loss: 0.1495 - acc: 0.9656
# Epoch 00047: val_loss did not improve from 0.46146
# 49/49 [==============================] - 13s 268ms/step - loss: 0.1525 - acc: 0.9623 - val_loss: 0.4780 - val_acc: 0.8704
# Epoch 48/100
# 48/49 [============================>.] - ETA: 0s - loss: 0.1526 - acc: 0.9729
# Epoch 00048: val_loss improved from 0.46146 to 0.44437, saving model to ./saved_models/Xception-Fine-Tune.h5
# 49/49 [==============================] - 15s 302ms/step - loss: 0.1531 - acc: 0.9714 - val_loss: 0.4444 - val_acc: 0.8704
# Epoch 49/100
# 48/49 [============================>.] - ETA: 0s - loss: 0.1797 - acc: 0.9500
# Epoch 00049: val_loss improved from 0.44437 to 0.43069, saving model to ./saved_models/Xception-Fine-Tune.h5
# 49/49 [==============================] - 15s 314ms/step - loss: 0.1794 - acc: 0.9511 - val_loss: 0.4307 - val_acc: 0.8519
# Epoch 50/100
# 48/49 [============================>.] - ETA: 0s - loss: 0.1060 - acc: 0.9833
# Epoch 00050: val_loss did not improve from 0.43069
# 49/49 [==============================] - 13s 268ms/step - loss: 0.1047 - acc: 0.9837 - val_loss: 0.4503 - val_acc: 0.8519
# Epoch 51/100
# 48/49 [============================>.] - ETA: 0s - loss: 0.1475 - acc: 0.9646
# Epoch 00051: val_loss did not improve from 0.43069
# 49/49 [==============================] - 13s 266ms/step - loss: 0.1463 - acc: 0.9653 - val_loss: 0.4952 - val_acc: 0.8519
# Epoch 52/100
# 48/49 [============================>.] - ETA: 0s - loss: 0.1556 - acc: 0.9615
# Epoch 00052: val_loss did not improve from 0.43069
# 49/49 [==============================] - 13s 266ms/step - loss: 0.1559 - acc: 0.9603 - val_loss: 0.5291 - val_acc: 0.8333
# Epoch 53/100
# 48/49 [============================>.] - ETA: 0s - loss: 0.1125 - acc: 0.9792
# Epoch 00053: val_loss did not improve from 0.43069
# 49/49 [==============================] - 13s 267ms/step - loss: 0.1107 - acc: 0.9796 - val_loss: 0.5126 - val_acc: 0.8519
# Epoch 54/100
# 48/49 [============================>.] - ETA: 0s - loss: 0.1057 - acc: 0.9771
# Epoch 00054: val_loss did not improve from 0.43069
# 49/49 [==============================] - 13s 268ms/step - loss: 0.1044 - acc: 0.9775 - val_loss: 0.4818 - val_acc: 0.8519
# Epoch 00054: early stopping

# %%
training_loss = model_history.history['loss']
val_loss = model_history.history['val_loss']

plt.plot(training_loss, label="training_loss")
plt.plot(val_loss, label="validation_loss")
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.title("Learning Curve")
plt.legend(loc='best')
plt.show()

# %%
training_acc = model_history.history['acc']
val_acc = model_history.history['val_acc']

plt.plot(training_acc, label="training_acc")
plt.plot(val_acc, label="validation_acc")
plt.xlabel("Epochs")
plt.ylabel("Acc")
plt.title("Learning Curve")
plt.legend(loc='best')
plt.show()

# %%
X_test, X_id = load_test_data(Gray2RGB=True, mean_proc=None, img_size=299)

model = load_model(model_path)

scores = model.evaluate(X_valid, y_valid, verbose=1)
print('Validation loss:', scores[0])
print('Validation accuracy:', scores[1])

y_test_pred_prob = model.predict(X_test)
y_test_pred = y_test_pred_prob.argmax(axis=-1)
y_test_pred_df = pd.DataFrame({'id': np.array(X_id), 'class':y_test_pred}).sort_values(by='id')
y_test_pred_df.to_csv('./submissions/{}.csv'.format(model_name), index=False)
# Out:
# 54/54 [==============================] - 2s 34ms/step
# Validation loss: 0.4306860488873941
# Validation accuracy: 0.851851862889749
